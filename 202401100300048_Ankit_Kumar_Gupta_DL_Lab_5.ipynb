# %%
import numpy as np
import pandas as pd

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow import keras
max_features = 10000
maxlen = 200

(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data(num_words=max_features)

X_train = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)

# %%
from tensorflow.keras import layers
def make_rnn():
    return keras.Sequential([
        layers.Embedding(max_features, 128, input_length=maxlen),
        layers.SimpleRNN(128),
        layers.Dense(1, activation='sigmoid')
    ])

def make_lstm():
    return keras.Sequential([
        layers.Embedding(max_features, 128, input_length=maxlen),
        layers.LSTM(128),
        layers.Dense(1, activation='sigmoid')
    ])

def make_gru():
    return keras.Sequential([
        layers.Embedding(max_features, 128, input_length=maxlen),
        layers.GRU(128),
        layers.Dense(1, activation='sigmoid')
    ])

models = {
    "RNN": make_rnn(),
    "LSTM": make_lstm(),
    "GRU": make_gru()
}
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
for name, model in models.items():
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    print(f"{name} compiled!")
# Out:
# RNN compiled!
# LSTM compiled!
# GRU compiled!

# %%
print(X_train.dtype)
print(type(X_train))
# Out:
# int32
# <class 'numpy.ndarray'>

# %%
history = {}

for name, model in models.items():
    print(f"\nTraining {name}...\n")

    history[name] = model.fit(
        X_train, y_train,
        epochs=5,
        batch_size=64,
        validation_split=0.2,
        verbose=1
    )
# Out:
# Training RNN...
#
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 130ms/step - accuracy: 0.6578 - loss: 0.6130 - val_accuracy: 0.5732 - val_loss: 0.6672
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 148ms/step - accuracy: 0.7128 - loss: 0.5766 - val_accuracy: 0.4884 - val_loss: 0.7517
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 138ms/step - accuracy: 0.6486 - loss: 0.6359 - val_accuracy: 0.6158 - val_loss: 0.6423
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 130ms/step - accuracy: 0.7060 - loss: 0.5730 - val_accuracy: 0.6486 - val_loss: 0.6287
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.7369 - loss: 0.5186 - val_accuracy: 0.6700 - val_loss: 0.6173
#
# Training LSTM...
#
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 158s 495ms/step - accuracy: 0.7952 - loss: 0.4355 - val_accuracy: 0.8554 - val_loss: 0.3374
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 157s 501ms/step - accuracy: 0.8611 - loss: 0.3373 - val_accuracy: 0.8428 - val_loss: 0.3699
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 163s 522ms/step - accuracy: 0.9110 - loss: 0.2295 - val_accuracy: 0.8502 - val_loss: 0.3573
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 211s 551ms/step - accuracy: 0.9399 - loss: 0.1626 - val_accuracy: 0.8498 - val_loss: 0.3653
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 151s 484ms/step - accuracy: 0.9575 - loss: 0.1205 - val_accuracy: 0.8488 - val_loss: 0.4717
#
# Training GRU...
#
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 157s 493ms/step - accuracy: 0.7383 - loss: 0.5095 - val_accuracy: 0.8412 - val_loss: 0.3686
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 152s 486ms/step - accuracy: 0.8866 - loss: 0.2789 - val_accuracy: 0.8668 - val_loss: 0.3211
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 151s 484ms/step - accuracy: 0.9265 - loss: 0.1918 - val_accuracy: 0.8524 - val_loss: 0.3366
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 202s 484ms/step - accuracy: 0.9541 - loss: 0.1325 - val_accuracy: 0.8618 - val_loss: 0.3989
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 150s 480ms/step - accuracy: 0.9682 - loss: 0.0896 - val_accuracy: 0.8640 - val_loss: 0.4633

# %%
results = {}

for name, model in models.items():
    print(f"\nEvaluating {name}...\n")

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    results[name] = acc

    print(f"{name} Test Accuracy: {acc:.4f}")
# Out:
# Evaluating RNN...
#
# RNN Test Accuracy: 0.6697
#
# Evaluating LSTM...
#
# LSTM Test Accuracy: 0.8482
#
# Evaluating GRU...
#
# GRU Test Accuracy: 0.8598
